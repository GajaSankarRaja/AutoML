# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.9/485.9 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.7/257.7 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 31.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.9 MB/s eta 0:00:00
# ...

# %%
#SETTING THE DATAFRRAME:
import pandas as pd
d=pd.read_csv('/content/drive/MyDrive/Datasets/data.csv')

# %%
#IMPORTING THE REGRESSION MODEL:
from pycaret.regression import *

# %%
#SETTING UP THE TARGET:
setup(d,target='RICE YIELD (Kg per ha)')
# Out:
# <style type="text/css">
# #T_9880a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9880a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9880a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9880a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9880a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9880a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9880a_row0_col1" class="data row0 col1" >6217</td>
#     </tr>
#     <tr>
#       <th id="T_9880a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9880a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9880a_row1_col1" class="data row1 col1" >RICE YIELD (Kg per ha)</td>
#     </tr>
#     <tr>
# ...

# %%
#COMPARING THE MODELS OBTAINED:
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_b3a2a th {
#   text-align: left;
# }
# ...

# %%
final_model=finalize_model(best_model)

# %%
#DISPLAYING THE BEST MODEL ATTAINED:
pre=predict_model(final_model,data=d)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b766" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b766_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2b766_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2b766_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2b766_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2b766_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2b766_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2b766_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b766_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b766_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_2b766_row0_col1" class="data row0 col1" >49.7342</td>
# ...
